# %% [markdown]
# # Dictionary: Ordered Associative Array

# %%
my_dictionary = {
    "alpha": 1,
    "beta": 2,
    "gamma": 3,
    "zeta": 42,
}

print(my_dictionary)
# Out:
# {'alpha': 1, 'beta': 2, 'gamma': 3, 'zeta': 42}

# %% [markdown]
# ### Adding an item:

# %%
my_dictionary["delta"] = 4
print(my_dictionary)
# Out:
# {'alpha': 1, 'beta': 2, 'gamma': 3, 'delta': 4}

# %% [markdown]
# ### Removing an item:

# %%
z = my_dictionary.pop("zeta")
print(my_dictionary)
# Out:
# {'alpha': 1, 'beta': 2, 'gamma': 3, 'delta': 4}

# %% [markdown]
# ### Printing the Keys and Values:

# %%
dict_keys = my_dictionary.keys()
dict_vals = my_dictionary.values()

print(dict_keys)
print(dict_vals)
# Out:
# dict_keys(['alpha', 'beta', 'gamma', 'delta'])
# dict_values([1, 2, 3, 4])

# %% [markdown]
# ## Dictionary Iteration
#
# The following is only possible because dictionaries are ordered - they maintain the order you give them. In previous versions of Python, dictionaries were not ordered, in fact - they were randomized.

# %% [markdown]
# Printing Keys Only

# %%
for key in my_dictionary.keys():
    print(key)
# Out:
# alpha
# beta
# gamma
# delta

# %% [markdown]
# Printing Values Only

# %%
for value in my_dictionary.values():
    print(value)
# Out:
# 1
# 2
# 3
# 4

# %% [markdown]
# Printing Keys and Values with Formatting

# %%
for key, val in my_dictionary.items():
    print(f"{key}: {val}")
# Out:
# alpha: 1
# beta: 2
# gamma: 3
# delta: 4

# %% [markdown]
# ### Dictionary Comprehension

# %%
char = ('a', 'b', 'c', 'd', 'e', 'f')
nums = ( 0,   1,   2,   3,   4,   5 )

dict_comp = {k: v for k, v in zip(char, nums)}

print(dict_comp)
# Out:
# {'a': 0, 'b': 1, 'c': 2, 'd': 3, 'e': 4, 'f': 5}
